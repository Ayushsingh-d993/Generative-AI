# %% [markdown]
# <a href="https://colab.research.google.com/github/Ayushsingh-d993/Generative-AI/blob/main/Untitled17.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
#
# # **AI ChatBot  ***

# %%
# This is importing an  some important library for making an AI ChatBOt.

# !pip install streamlit
# !pip install langchain-mistralai
# !pip install -q langchain langchain-openai python-dotenv
# !pip install -q streamlit pyngrok langchain langchain-core langchain-mistralai python-dotenv
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.2/9.2 MB 58.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.3/11.3 MB 89.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 548.1/548.1 kB 10.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: langchain-core
#     Found existing installation: langchain-core 1.3.1
#     Uninstalling langchain-core-1.3.1:
#       Successfully uninstalled langchain-core-1.3.1
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 3.3 MB/s eta 0:00:00

# %%
# This is creating an API KEY of Mistral AI on his official website.

MISTRAL_API_KEY = "mqZKzLAzOXwIjeCROPeLceW7HGRGAva9"

# %%
# Pass your API KEY form here.
import os

from getpass import getpass
os.environ["MISTRAL_API_KEY"] = getpass("Enter your mistral api key: ")

# %%
# This is creating a file app.py where you write the actual code of the model that we make and also make an UI for this model using Streamlit.

# %%writefile app.py

from dotenv import load_dotenv
load_dotenv()

import streamlit as st

from langchain_mistralai import ChatMistralAI
from langchain_core.messages import (
    AIMessage,
    HumanMessage,
    SystemMessage
)

# Page config
st.set_page_config(
    page_title="Mood AI Chatbot",
    page_icon="🤖",
    layout="centered"
)

st.title("🤖 Mood AI Chatbot")

# Sidebar
st.sidebar.title("Choose AI Mode")

mode_option = st.sidebar.selectbox(
    "Select Mode",
    ["Angry", "Funny", "Sad"]
)

# Mode prompts
if mode_option == "Angry":
    mode = "You are an angry AI agent. You respond aggressively and impatiently."

elif mode_option == "Funny":
    mode = "You are a funny AI agent. You respond with humor and jokes."

elif mode_option == "Sad":
    mode = "You are a sad AI agent. You respond emotionally and sadly."

# Load model
model = ChatMistralAI(
    model="mistral-small-2506",
    temperature=0.9
)

# Session state
if "messages" not in st.session_state:
    st.session_state.messages = [
        SystemMessage(content=mode)
    ]

# Display previous chat
for msg in st.session_state.messages[1:]:

    if isinstance(msg, HumanMessage):
        with st.chat_message("user"):
            st.write(msg.content)

    elif isinstance(msg, AIMessage):
        with st.chat_message("assistant"):
            st.write(msg.content)

# Chat input
user_input = st.chat_input("Type your message...")

if user_input:

    # Store user message
    st.session_state.messages.append(
        HumanMessage(content=user_input)
    )

    # Show user message
    with st.chat_message("user"):
        st.write(user_input)

    # Generate AI response
    response = model.invoke(st.session_state.messages)

    # Store AI response
    st.session_state.messages.append(
        AIMessage(content=response.content)
    )

    # Show AI response
    with st.chat_message("assistant"):
        st.write(response.content)

# %%
# Create a Authtoken of ngrok which help to make the UI and locally host it. This token is created by the official website of ngrok after this you will pass form that code.

from pyngrok import ngrok

ngrok.set_auth_token("3DfHGtwpbjzkKD5vj0ZOoE861AC_5cH97Z3M7f1oRicRaEdTL")

# %%
# When authtoken is not working properly then use this code to delete it, and generate a new one.

# !rm -rf /root/.ngrok2

# %%
# This is created for run the file  which is app.py.

# !streamlit run app.py &>/content/logs.txt &

# %%
# Then we connect the ngrok with public url for host locally.

from pyngrok import ngrok

public_url = ngrok.connect(8501)

print(public_url)
